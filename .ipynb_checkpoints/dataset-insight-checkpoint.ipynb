# %%
import pandas as pd
import numpy as np
from scipy.stats import pearsonr

# %% [markdown]
# # Data Understanding

# %%
mvps_df = pd.read_csv("datasets/mvps.csv",";")
nicknames_df = pd.read_csv("datasets/nicknames.csv",";")
player_mvp_stats_df = pd.read_csv("datasets/player_mvp_stats.csv",";")
players_df = pd.read_csv("datasets/players.csv",";")
salaries_df = pd.read_csv("datasets/salaries.csv")
teams_df = pd.read_csv("datasets/teams.csv",";")
# Out:
# C:\Users\ASUS-GAMING\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3369: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\ASUS-GAMING\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3369: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\ASUS-GAMING\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3369: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\ASUS-GAMING\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3369: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\ASUS-GAMING\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3369: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# Rank : urutan ranking mvp pada periode tahun berikut
#
# Tm : Tim dari player
#
# First : First Place Votes
#
# Pts Won : Points Won
#
# Pts Max : Max points
#
# Share : Points Share
#
# G : Games Played
#
# MP : avg minutes per game
#
# PTS : avg point per game
#
# TRB : avg total rebound per game
#
# AST : avg total assists per game
#
# STL : avg steal per game
#
# BLK : avg block per game

# %%
display_cnt = 15
def display_both_head_and_tail(dataset):
    return dataset.head(display_cnt).append(dataset.tail(display_cnt))

# %%
def cek_missing_values(df):
    col_na = df.isnull().sum().sort_values(ascending=False)
    percent = col_na / len(df)
    
    missing_data = pd.concat([col_na, percent], axis=1, keys=['Total', 'Percent'])
    return missing_data[missing_data['Total'] > 0]

# %% [markdown]
# Dataset mvps

# %%
display_both_head_and_tail(mvps_df)
# Out:
# C:\Users\ASUS-GAMING\AppData\Local\Temp\ipykernel_16356\276291969.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return dataset.head(display_cnt).append(dataset.tail(display_cnt))
#     Rank                 Player  Age   Tm  First  Pts Won  Pts Max   Share  \
# 0      1         Michael Jordan   27  CHI     77      891      960  928.00
# 1      2          Magic Johnson   31  LAL     10      497      960  518.00
# 2      3         David Robinson   25  SAS      6      476      960  496.00
# 3      4        Charles Barkley   27  PHI      2      222      960  231.00
# 4      5            Karl Malone   27  UTA      0      142      960  148.00
# 5      6          Clyde Drexler   28  POR      1       75      960   78.00
# 6      7          Kevin Johnson   24  PHO      0       32      960   33.00
# 7      8      Dominique Wilkins   31  ATL      0       29      960    0.03
# 8     9T             Larry Bird   34  BOS      0       25      960   26.00
# 9     9T           Terry Porter   27  POR      0       25      960   26.00
# 10    11          Patrick Ewing   28  NYK      0       20      960   21.00
# 11    12          John Stockton   28  UTA      0       15      960   16.00
# 12    13           Isiah Thomas   29  DET      0       11      960   11.00
# 13    14          Robert Parish   37  BOS      0       10      960    0.01
# 14    15             Joe Dumars   27  DET      0        8      960    8.00
# 459    1           Nikola Joki?   25  DEN     91      971     1010  961.00
# 460    2            Joel Embiid   26  PHI      1      586     1010    0.58
# 461    3          Stephen Curry   32  GSW      5      453     1010  449.00
# 462    4  Giannis Antetokounmpo   26  MIL      1      348     1010  345.00
# 463    5             Chris Paul   35  PHO      2      139     1010  138.00
# 464    6            Luka Don?i?   21  DAL      0       42     1010   42.00
# 465    7         Damian Lillard   30  POR      0       38     1010   38.00
# 466    8          Julius Randle   26  NYK      0       20     1010    0.02
# 467    9           Derrick Rose   32  TOT      1       10     1010    0.01
# 468   10            Rudy Gobert   28  UTA      0        8     1010    8.00
# 469   11      Russell Westbrook   32  WAS      0        5     1010    5.00
# 470   12            Ben Simmons   24  PHI      0        3     1010    3.00
# 471  13T           James Harden   31  TOT      0        1     1010    1.00
# 472  13T           LeBron James   36  LAL      0        1     1010    1.00
# 473  13T          Kawhi Leonard   29  LAC      0        1     1010    1.00
#
#       G    MP  ...   TRB   AST  STL  BLK     FG%     3P%     FT%    WS  \
# 0    82  37.0  ...   6.0   5.5  2.7  1.0  539.00  312.00  851.00  20.3
# 1    79  37.1  ...   7.0  12.5  1.3  0.2  477.00    0.32  906.00  15.4
# 2    82  37.7  ...  13.0   2.5  1.5  3.9  552.00  143.00  762.00  17.0
# 3    67  37.3  ...  10.1   4.2  1.6  0.5    0.57  284.00  722.00  13.4
# 4    82  40.3  ...  11.8   3.3  1.1  1.0  527.00  286.00    0.77  15.5
# 5    82  34.8  ...   6.7   6.0  1.8  0.7  482.00  319.00  794.00  12.4
# 6    77  36.0  ...   3.5  10.1  2.1  0.1  516.00  205.00  843.00  12.7
# 7    81  38.0  ...   9.0   3.3  1.5  0.8    0.47  341.00  829.00  11.4
# 8    60  38.0  ...   8.5   7.2  1.8  1.0  454.00  389.00  891.00   6.6
# 9    81  32.9  ...   3.5   8.0  2.0  0.1  515.00  415.00  823.00  13.0
# 10   81  38.3  ...  11.2   3.0  1.0  3.2  514.00    0.00  745.00  10.0
# 11   82  37.8  ...   2.9  14.2  2.9  0.2  507.00  345.00  836.00  14.0
# 12   48  34.5  ...   3.3   9.3  1.6  0.2  435.00  292.00  782.00   3.4
# 13   81  30.1  ...  10.6   0.8  0.8  1.3  598.00    0.00  767.00  10.0
# 14   80  38.1  ...   2.3   5.5  1.1  0.1  481.00  311.00    0.89   9.9
# 459  72  34.6  ...  10.8   8.3  1.3  0.7  566.00  388.00  868.00  15.6
# 460  51  31.1  ...  10.6   2.8  1.0  1.4  513.00  377.00  859.00   8.8
# 461  63  34.2  ...   5.5   5.8  1.2  0.1  482.00  421.00  916.00   9.0
# 462  61  33.0  ...  11.0   5.9  1.2  1.2  569.00  303.00  685.00  10.2
# 463  70  31.4  ...   4.5   8.9  1.4  0.3  499.00  395.00  934.00   9.2
# 464  66  34.3  ...   8.0   8.6  1.0  0.5  479.00    0.35    0.73   7.7
# 465  67  35.8  ...   4.2   7.5  0.9  0.3  451.00  391.00  928.00  10.4
# 466  71  37.6  ...  10.2   6.0  0.9  0.3  456.00  411.00  811.00   7.8
# 467  50  25.6  ...   2.6   4.2  1.0  0.4    0.47  388.00  866.00   3.1
# 468  71  30.8  ...  13.5   1.3  0.6  2.7  675.00    0.00  623.00  11.3
# 469  65  36.4  ...  11.5  11.7  1.4  0.4  439.00  315.00  656.00   3.7
# 470  58  32.4  ...   7.2   6.9  1.6  0.6  557.00    0.30  613.00   6.0
# 471  44  36.6  ...   7.9  10.8  1.2  0.8  466.00  362.00  861.00   7.0
# 472  45  33.4  ...   7.7   7.8  1.1  0.6  513.00  365.00  698.00   5.6
# 473  52  34.1  ...   6.5   5.2  1.6  0.4  512.00  398.00  885.00   8.8
#
#       WS/48  Year
# 0    321.00  1991
# 1    251.00  1991
# 2    264.00  1991
# 3    258.00  1991
# 4    225.00  1991
# 5    209.00  1991
# 6      0.22  1991
# 7    177.00  1991
# 8      0.14  1991
# 9    235.00  1991
# 10   155.00  1991
# 11   217.00  1991
# 12    98.00  1991
# 13   198.00  1991
# 14   155.00  1991
# 459  301.00  2021
# 460  266.00  2021
# 461  201.00  2021
# 462  244.00  2021
# 463  201.00  2021
# 464  163.00  2021
# 465  209.00  2021
# 466    0.14  2021
# 467  118.00  2021
# 468  248.00  2021
# 469   75.00  2021
# 470  153.00  2021
# 471  208.00  2021
# 472  179.00  2021
# 473  238.00  2021
#
# [30 rows x 21 columns]

# %%
mvps_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 474 entries, 0 to 473
# Data columns (total 21 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     474 non-null    object
#  1   Player   474 non-null    object
#  2   Age      474 non-null    int64
#  3   Tm       474 non-null    object
#  4   First    474 non-null    int64
#  5   Pts Won  474 non-null    int64
#  6   Pts Max  474 non-null    int64
#  7   Share    474 non-null    float64
#  8   G        474 non-null    int64
#  9   MP       474 non-null    float64
#  10  PTS      474 non-null    float64
#  11  TRB      474 non-null    float64
#  12  AST      474 non-null    float64
#  13  STL      474 non-null    float64
#  14  BLK      474 non-null    float64
#  15  FG%      474 non-null    float64
#  16  3P%      474 non-null    float64
#  17  FT%      474 non-null    float64
#  18  WS       474 non-null    float64
#  19  WS/48    474 non-null    float64
#  20  Year     474 non-null    int64
# dtypes: float64(12), int64(6), object(3)
# memory usage: 77.9+ KB

# %%
print("Tidak ditemukan missing value pada dataset mvps")
cek_missing_values(mvps_df)
# Out:
# Tidak ditemukan missing value pada dataset mvps
# Empty DataFrame
# Columns: [Total, Percent]
# Index: []

# %%
print("Jumlah duplikasi data pada dataset mvps:", mvps_df.duplicated().sum())
# Out:
# Jumlah duplikasi data pada dataset mvps: 0

# %% [markdown]
# Dataset nicknames

# %%
display_both_head_and_tail(nicknames_df)
# Out:
# C:\Users\ASUS-GAMING\AppData\Local\Temp\ipykernel_16356\276291969.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return dataset.head(display_cnt).append(dataset.tail(display_cnt))
#    Abbreviation                    Name
# 0           ATL           Atlanta Hawks
# 1           BRK           Brooklyn Nets
# 2           BKN           Brooklyn Nets
# 3           BOS          Boston Celtics
# 4           CHA       Charlotte Bobcats
# 5           CHH       Charlotte Hornets
# 6           CHO       Charlotte Hornets
# 7           CHI           Chicago Bulls
# 8           CLE     Cleveland Cavaliers
# 9           DAL        Dallas Mavericks
# 10          DEN          Denver Nuggets
# 11          DET         Detroit Pistons
# 12          GSW   Golden State Warriors
# 13          HOU         Houston Rockets
# 14          IND          Indiana Pacers
# 25          NYK         New York Knicks
# 26          OKC   Oklahoma City Thunder
# 27          ORL           Orlando Magic
# 28          PHI      Philadelphia 76ers
# 29          PHX            Phoenix Suns
# 30          PHO            Phoenix Suns
# 31          POR  Portland Trail Blazers
# 32          SEA     Seattle SuperSonics
# 33          SAC        Sacramento Kings
# 34          SAS       San Antonio Spurs
# 35          TOR         Toronto Raptors
# 36          UTA               Utah Jazz
# 37          VAN     Vancouver Grizzlies
# 38          WAS      Washington Wizards
# 39          WSB      Washington Bullets

# %%
nicknames_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Abbreviation  40 non-null     object
#  1   Name          40 non-null     object
# dtypes: object(2)
# memory usage: 768.0+ bytes

# %%
print("Tidak ditemukan missing value pada dataset nicknames")
cek_missing_values(nicknames_df)
# Out:
# Tidak ditemukan missing value pada dataset nicknames
# Empty DataFrame
# Columns: [Total, Percent]
# Index: []

# %%
print("Jumlah duplikasi data pada dataset nicknames:", nicknames_df.duplicated().sum())
# Out:
# Jumlah duplikasi data pada dataset nicknames: 0

# %% [markdown]
# Dataset player mvp stats

# %%
display_both_head_and_tail(player_mvp_stats_df)
# Out:
# C:\Users\ASUS-GAMING\AppData\Local\Temp\ipykernel_16356\276291969.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return dataset.head(display_cnt).append(dataset.tail(display_cnt))
#                     Player Pos  Age   Tm   G  GS    MP   FG   FGA     FG%  \
# 0               A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  476.00
# 1              Byron Scott  SG   29  LAL  82  82  32.1  6.1  12.8  477.00
# 2           Elden Campbell  PF   22  LAL  52   0   7.3  1.1   2.4  455.00
# 3            Irving Thomas  PF   25  LAL  26   0   4.2  0.7   1.9    0.34
# 4             James Worthy  SF   29  LAL  78  74  38.6  9.2  18.7  492.00
# 5               Larry Drew  PG   32  LAL  48   2  10.3  1.1   2.6  432.00
# 6            Magic Johnson  PG   31  LAL  79  79  37.1  5.9  12.4  477.00
# 7          Mychal Thompson   C   36  LAL  72   4  15.0  1.6   3.2  496.00
# 8              Sam Perkins  PF   29  LAL  73  66  34.3  5.0  10.2  495.00
# 9             Terry Teagle  SG   30  LAL  82   0  18.3  4.1   9.2  443.00
# 10              Tony Smith  SG   22  LAL  64   1  10.9  1.5   3.4  441.00
# 11             Vlade Divac   C   22  LAL  82  81  28.2  4.4   7.8  565.00
# 12              A.C. Green  PF   28  LAL  82  53  35.4  4.7   9.8  476.00
# 13             Byron Scott  SG   30  LAL  82  82  32.7  5.6  12.3  458.00
# 14            Chucky Brown  SF   23  LAL  42   2  10.3  1.4   3.0  469.00
# 14077          Greg Monroe   C   26  MIL  81   0  22.5  4.8   9.0  533.00
# 14078        Jabari Parker  PF   21  MIL  51  50  33.9  7.8  16.0    0.49
# 14079          Jason Terry  SG   39  MIL  74   0  18.4  1.4   3.3  432.00
# 14080          John Henson   C   26  MIL  58  39  19.4  2.7   5.3  515.00
# 14081      Khris Middleton  SF   25  MIL  29  23  30.7  5.2  11.5    0.45
# 14082      Malcolm Brogdon  SG   24  MIL  75  28  26.4  3.9   8.5  457.00
# 14083  Matthew Dellavedova  PG   26  MIL  76  54  26.1  2.7   7.0    0.39
# 14084      Michael Beasley  PF   28  MIL  56   6  16.7  3.9   7.3  532.00
# 14085      Mirza Teletovi?  PF   31  MIL  70   2  16.2  2.2   6.0  373.00
# 14086        Rashad Vaughn  SG   20  MIL  41   2  11.2  1.4   3.8  365.00
# 14087        Spencer Hawes  PF   28  MIL  54   1  14.8  2.5   5.1  484.00
# 14088          Steve Novak  PF   33  MIL   8   0   2.8  0.3   0.9  286.00
# 14089       Terrence Jones  PF   25  MIL  54  12  23.5  4.3   9.1    0.47
# 14090           Thon Maker   C   19  MIL  57  34   9.9  1.5   3.2  459.00
# 14091           Tony Snell  SG   25  MIL  80  80  29.2  3.1   6.8  455.00
#
#        ...  Pts Max  Share                Team   W   L   W/L%    GB   PS/G  \
# 0      ...        0    0.0  Los Angeles Lakers  58  24  707.0   5.0  106.3
# 1      ...        0    0.0  Los Angeles Lakers  58  24  707.0   5.0  106.3
# 2      ...        0    0.0  Los Angeles Lakers  58  24  707.0   5.0  106.3
# 3      ...        0    0.0  Los Angeles Lakers  58  24  707.0   5.0  106.3
# 4      ...        0    0.0  Los Angeles Lakers  58  24  707.0   5.0  106.3
# 5      ...        0    0.0  Los Angeles Lakers  58  24  707.0   5.0  106.3
# 6      ...      960  518.0  Los Angeles Lakers  58  24  707.0   5.0  106.3
# 7      ...        0    0.0  Los Angeles Lakers  58  24  707.0   5.0  106.3
# 8      ...        0    0.0  Los Angeles Lakers  58  24  707.0   5.0  106.3
# 9      ...        0    0.0  Los Angeles Lakers  58  24  707.0   5.0  106.3
# 10     ...        0    0.0  Los Angeles Lakers  58  24  707.0   5.0  106.3
# 11     ...        0    0.0  Los Angeles Lakers  58  24  707.0   5.0  106.3
# 12     ...        0    0.0  Los Angeles Lakers  43  39  524.0  14.0  100.4
# 13     ...        0    0.0  Los Angeles Lakers  43  39  524.0  14.0  100.4
# 14     ...        0    0.0  Los Angeles Lakers  43  39  524.0  14.0  100.4
# 14077  ...        0    0.0     Milwaukee Bucks  42  40  512.0   9.0  103.6
# 14078  ...        0    0.0     Milwaukee Bucks  42  40  512.0   9.0  103.6
# 14079  ...        0    0.0     Milwaukee Bucks  42  40  512.0   9.0  103.6
# 14080  ...        0    0.0     Milwaukee Bucks  42  40  512.0   9.0  103.6
# 14081  ...        0    0.0     Milwaukee Bucks  42  40  512.0   9.0  103.6
# 14082  ...        0    0.0     Milwaukee Bucks  42  40  512.0   9.0  103.6
# 14083  ...        0    0.0     Milwaukee Bucks  42  40  512.0   9.0  103.6
# 14084  ...        0    0.0     Milwaukee Bucks  42  40  512.0   9.0  103.6
# 14085  ...        0    0.0     Milwaukee Bucks  42  40  512.0   9.0  103.6
# 14086  ...        0    0.0     Milwaukee Bucks  42  40  512.0   9.0  103.6
# 14087  ...        0    0.0     Milwaukee Bucks  42  40  512.0   9.0  103.6
# 14088  ...        0    0.0     Milwaukee Bucks  42  40  512.0   9.0  103.6
# 14089  ...        0    0.0     Milwaukee Bucks  42  40  512.0   9.0  103.6
# 14090  ...        0    0.0     Milwaukee Bucks  42  40  512.0   9.0  103.6
# 14091  ...        0    0.0     Milwaukee Bucks  42  40  512.0   9.0  103.6
#
#         PA/G   SRS
# 0       99.6  6.73
# 1       99.6  6.73
# 2       99.6  6.73
# 3       99.6  6.73
# 4       99.6  6.73
# 5       99.6  6.73
# 6       99.6  6.73
# 7       99.6  6.73
# 8       99.6  6.73
# 9       99.6  6.73
# 10      99.6  6.73
# 11      99.6  6.73
# 12     101.5 -0.95
# 13     101.5 -0.95
# 14     101.5 -0.95
# 14077  103.8 -0.45
# 14078  103.8 -0.45
# 14079  103.8 -0.45
# 14080  103.8 -0.45
# 14081  103.8 -0.45
# 14082  103.8 -0.45
# 14083  103.8 -0.45
# 14084  103.8 -0.45
# 14085  103.8 -0.45
# 14086  103.8 -0.45
# 14087  103.8 -0.45
# 14088  103.8 -0.45
# 14089  103.8 -0.45
# 14090  103.8 -0.45
# 14091  103.8 -0.45
#
# [30 rows x 41 columns]

# %%
display_both_head_and_tail(player_mvp_stats_df)
player_mvp_stats_df.isna().sum()
temp = (player_mvp_stats_df['FG'] - (player_mvp_stats_df['2P'] + player_mvp_stats_df['3P'])) > 0.100001
player_mvp_stats_df[temp]
# Out:
# C:\Users\ASUS-GAMING\AppData\Local\Temp\ipykernel_16356\276291969.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return dataset.head(display_cnt).append(dataset.tail(display_cnt))
# Empty DataFrame
# Columns: [Player, Pos, Age, Tm, G, GS, MP, FG, FGA, FG%, 3P, 3PA, 3P%, 2P, 2PA, 2P%, eFG%, FT, FTA, FT%, ORB, DRB, TRB, AST, STL, BLK, TOV, PF, PTS, Year, Pts Won, Pts Max, Share, Team, W, L, W/L%, GB, PS/G, PA/G, SRS]
# Index: []
#
# [0 rows x 41 columns]

# %%
player_mvp_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14092 entries, 0 to 14091
# Data columns (total 41 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Player   14092 non-null  object
#  1   Pos      14092 non-null  object
#  2   Age      14092 non-null  int64
#  3   Tm       14092 non-null  object
#  4   G        14092 non-null  int64
#  5   GS       14092 non-null  int64
#  6   MP       14092 non-null  float64
#  7   FG       14092 non-null  float64
#  8   FGA      14092 non-null  float64
#  9   FG%      14042 non-null  float64
#  10  3P       14092 non-null  float64
#  11  3PA      14092 non-null  float64
#  12  3P%      12050 non-null  float64
#  13  2P       14092 non-null  float64
#  14  2PA      14092 non-null  float64
#  15  2P%      14008 non-null  float64
#  16  eFG%     14042 non-null  float64
#  17  FT       14092 non-null  float64
#  18  FTA      14092 non-null  float64
#  19  FT%      13630 non-null  float64
#  20  ORB      14092 non-null  float64
#  21  DRB      14092 non-null  float64
#  22  TRB      14092 non-null  float64
#  23  AST      14092 non-null  float64
#  24  STL      14092 non-null  float64
#  25  BLK      14092 non-null  float64
#  26  TOV      14092 non-null  float64
#  27  PF       14092 non-null  float64
#  28  PTS      14092 non-null  float64
#  29  Year     14092 non-null  int64
#  30  Pts Won  14092 non-null  int64
#  31  Pts Max  14092 non-null  int64
#  32  Share    14092 non-null  float64
#  33  Team     14092 non-null  object
#  34  W        14092 non-null  int64
#  35  L        14092 non-null  int64
#  36  W/L%     14092 non-null  float64
#  37  GB       14092 non-null  float64
#  38  PS/G     14092 non-null  float64
#  39  PA/G     14092 non-null  float64
#  40  SRS      14092 non-null  float64
# dtypes: float64(29), int64(8), object(4)
# memory usage: 4.4+ MB

# %%
print("Terdapat missing values pada dataset player mvp stats")
cek_missing_values(player_mvp_stats_df)
# Out:
# Terdapat missing values pada dataset player mvp stats
#       Total   Percent
# 3P%    2042  0.144905
# FT%     462  0.032785
# 2P%      84  0.005961
# eFG%     50  0.003548
# FG%      50  0.003548

# %%
print("Missing values tersebut diisi dengan median setiap atribut")

player_mvp_stats_df["3P%"].fillna(player_mvp_stats_df["3P%"].median(), inplace=True)
player_mvp_stats_df["FT%"].fillna(player_mvp_stats_df["FT%"].median(), inplace=True)
player_mvp_stats_df["2P%"].fillna(player_mvp_stats_df["2P%"].median(), inplace=True)
player_mvp_stats_df["eFG%"].fillna(player_mvp_stats_df["eFG%"].median(), inplace=True)
player_mvp_stats_df["FG%"].fillna(player_mvp_stats_df["FG%"].median(), inplace=True)
# Out:
# Missing values tersebut diisi dengan median setiap atribut

# %%
print("Sudah tidak ada missing value pada dataset palyer mvp stats")
cek_missing_values(player_mvp_stats_df)
# Out:
# Sudah tidak ada missing value pada dataset palyer mvp stats
# Empty DataFrame
# Columns: [Total, Percent]
# Index: []

# %%
print("Jumlah duplikasi data pada dataset palyer mvp stats:", player_mvp_stats_df.duplicated().sum())
# Out:
# Jumlah duplikasi data pada dataset palyer mvp stats: 0

# %% [markdown]
# Dataset players

# %%
display_both_head_and_tail(players_df)
# Out:
# C:\Users\ASUS-GAMING\AppData\Local\Temp\ipykernel_16356\276291969.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return dataset.head(display_cnt).append(dataset.tail(display_cnt))
#         Rk              Player    Pos Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0        1      Alaa Abdelnaby     PF  22  POR  43   0   6.7  1.3   2.7  ...
# 1        2  Mahmoud Abdul-Rauf     PG  21  DEN  67  19  22.5  6.2  15.1  ...
# 2        3          Mark Acres      C  28  ORL  68   0  19.3  1.6   3.1  ...
# 3        4       Michael Adams     PG  28  DEN  66  66  35.5  8.5  21.5  ...
# 4        5        Mark Aguirre     SF  31  DET  78  13  25.7  5.4  11.7  ...
# 5        6         Danny Ainge     SG  31  POR  80   0  21.4  4.2   8.9  ...
# 6        7         Mark Alarie     PF  27  WSB  42   1    14  2.4   5.4  ...
# 7        8        Steve Alford     PG  26  DAL  34   0   6.9  1.7   3.4  ...
# 8        9       Greg Anderson     PF  26  TOT  68   2  13.6  1.7     4  ...
# 9        9       Greg Anderson     PF  26  MIL  26   0   9.5    1   2.8  ...
# 10       9       Greg Anderson     PF  26  NJN   1   0    18    4     4  ...
# 11       9       Greg Anderson     PF  26  DEN  41   2  16.1  2.1   4.7  ...
# 12      10       Nick Anderson     SG  23  ORL  70  42  28.2  5.7  12.2  ...
# 13      11        Ron Anderson     SF  32  PHI  82  13  28.5  6.2  12.9  ...
# 14      12     Willie Anderson     SG  24  SAS  75  75  34.6    6  13.2  ...
# 18029  529         D.J. Wilson     PF  24  MIL  12   0   8.8  1.3   3.6  ...
# 18030  529         D.J. Wilson     PF  24  HOU  23   1  14.3  2.3   5.4  ...
# 18031  530       Dylan Windler     SF  24  CLE  31   0  16.5  1.8   4.2  ...
# 18032  531     Justise Winslow     SF  24  MEM  26   1  19.5  2.8   8.1  ...
# 18033  532     Cassius Winston     PG  22  WAS  22   0   4.5  0.6   1.5  ...
# 18034  533       James Wiseman      C  19  GSW  39  27  21.4  4.9   9.4  ...
# 18035  534      Christian Wood      C  25  HOU  41  41  32.3    8  15.6  ...
# 18036  535   Robert Woodard II     SF  21  SAC  13   0   3.5  0.6   1.5  ...
# 18037  536        Delon Wright  SG-PG  28  TOT  63  39  27.7  3.8   8.2  ...
# 18038  536        Delon Wright     SG  28  DET  36  31  29.2  3.8   8.1  ...
# 18039  536        Delon Wright     PG  28  SAC  27   8  25.8  3.9   8.3  ...
# 18040  537      Thaddeus Young     PF  32  CHI  68  23  24.3  5.4   9.7  ...
# 18041  538          Trae Young     PG  22  ATL  63  63  33.7  7.7  17.7  ...
# 18042  539         Cody Zeller      C  28  CHO  48  21  20.9  3.8   6.8  ...
# 18043  540         Ivica Zubac      C  23  LAC  72  33  22.3  3.6   5.5  ...
#
#        ORB  DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Year
# 0      0.6  1.4  2.1   0.3  0.1  0.3  0.5  0.9   3.1  1991
# 1      0.5  1.3  1.8   3.1  0.8  0.1  1.6  2.2  14.1  1991
# 2      2.1  3.2  5.3   0.4  0.4  0.4  0.6  3.2   4.2  1991
# 3      0.9    3  3.9  10.5  2.2  0.1  3.6  2.5  26.5  1991
# 4      1.7  3.1  4.8   1.8  0.6  0.3  1.6  2.7  14.2  1991
# 5      0.6    2  2.6   3.6  0.8  0.2  1.3  2.4  11.1  1991
# 6        1  1.8  2.8   1.1  0.4  0.2    1  2.1   5.8  1991
# 7      0.3  0.4  0.7   0.6  0.2    0  0.5  0.3   4.4  1991
# 8      1.4  3.3  4.7   0.2  0.5  0.7  1.2  2.1   4.3  1991
# 9        1  1.9  2.9   0.1  0.3  0.3  0.8  1.1   2.7  1991
# 10       4    2    6     1    2    0    1    4     8  1991
# 11     1.6  4.1  5.8   0.3  0.6  0.9  1.5  2.6   5.2  1991
# 12     1.3  4.2  5.5   1.5  1.1  0.6  1.6  2.1  14.1  1991
# 13     1.3  3.2  4.5   1.4  0.8  0.2  1.2    2  14.6  1991
# 14     0.9  3.8  4.7   4.8  1.1  0.6  2.2    3  14.4  1991
# 18029  0.3  1.8  2.1   0.3  0.1  0.3  0.3  1.1   3.6  2021
# 18030  0.7    3  3.8   0.9  0.4  0.5  0.8  1.3   6.1  2021
# 18031  0.6  2.8  3.5   1.1  0.6  0.4    1  1.2   5.2  2021
# 18032  0.7  3.8  4.5   1.9  0.6  0.5  1.4  1.8   6.8  2021
# 18033    0  0.4  0.4   0.5  0.1    0  0.2  0.4   1.9  2021
# 18034  1.4  4.4  5.8   0.7  0.3  0.9  1.5  3.1  11.5  2021
# 18035  1.9  7.8  9.6   1.7  0.8  1.2    2  2.1    21  2021
# 18036  0.3  0.9  1.2   0.2    0  0.2  0.1  0.3   1.5  2021
# 18037    1  3.2  4.3   4.4  1.6  0.5  1.3  1.2  10.2  2021
# 18038    1  3.5  4.6     5  1.6  0.5  1.3  1.3  10.4  2021
# 18039    1  2.9  3.9   3.6  1.6  0.4  1.3  1.1    10  2021
# 18040  2.5  3.8  6.2   4.3  1.1  0.6    2  2.2  12.1  2021
# 18041  0.6  3.3  3.9   9.4  0.8  0.2  4.1  1.8  25.3  2021
# 18042  2.5  4.4  6.8   1.8  0.6  0.4  1.1  2.5   9.4  2021
# 18043  2.6  4.6  7.2   1.3  0.3  0.9  1.1  2.6     9  2021
#
# [30 rows x 31 columns]

# %%
players_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18044 entries, 0 to 18043
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rk      18044 non-null  object
#  1   Player  18044 non-null  object
#  2   Pos     18044 non-null  object
#  3   Age     18044 non-null  object
#  4   Tm      18044 non-null  object
#  5   G       18044 non-null  object
#  6   GS      18044 non-null  object
#  7   MP      18044 non-null  object
#  8   FG      18044 non-null  object
#  9   FGA     18044 non-null  object
#  10  FG%     18044 non-null  object
#  11  3P      18044 non-null  object
#  12  3PA     18044 non-null  object
#  13  3P%     18044 non-null  object
#  14  2P      18044 non-null  object
#  15  2PA     18044 non-null  object
#  16  2P%     18044 non-null  object
#  17  eFG%    18044 non-null  object
#  18  FT      18044 non-null  object
#  19  FTA     18044 non-null  object
#  20  FT%     18044 non-null  object
#  21  ORB     18044 non-null  object
#  22  DRB     18044 non-null  object
#  23  TRB     18044 non-null  object
#  24  AST     18044 non-null  object
#  25  STL     18044 non-null  object
#  26  BLK     18044 non-null  object
#  27  TOV     18044 non-null  object
#  28  PF      18044 non-null  object
#  29  PTS     18044 non-null  object
#  30  Year    18044 non-null  int64
# dtypes: int64(1), object(30)
# memory usage: 4.3+ MB

# %%
print("Tidak ditemukan missing value pada dataset players")
cek_missing_values(players_df)
# Out:
# Tidak ditemukan missing value pada dataset players
# Empty DataFrame
# Columns: [Total, Percent]
# Index: []

# %%
print("Jumlah duplikasi data pada dataset mvps:", players_df.duplicated().sum(), "maka lakukan drop data terlebih dahulu")

players_df = players_df.drop_duplicates(inplace = False)
print("Jumlah duplikasi data setelah drop duplikasinya:", players_df.duplicated().sum())
# Out:
# Jumlah duplikasi data pada dataset mvps: 627 maka lakukan drop data terlebih dahulu
# Jumlah duplikasi data setelah drop duplikasinya: 0

# %%
# Terdapat row yang berisi nama dari row tersebut
wrong_value = players_df.loc[players_df['Rk'] == 'Rk']
wrong_value
# Out:
#        Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST  \
# 47     Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 507    Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 983    Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 1451   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 1948   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 2421   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 2991   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 3589   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 4146   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 4673   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 5189   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 5751   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 6267   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 6780   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 7388   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 7993   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 8563   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 9108   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 9722   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 10322  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 10937  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 11564  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 12146  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 12744  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 13372  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 14042  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 14644  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 15262  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 15953  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 16690  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
# 17364  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  ORB  DRB  TRB  AST
#
#        STL  BLK  TOV  PF  PTS  Year
# 47     STL  BLK  TOV  PF  PTS  1991
# 507    STL  BLK  TOV  PF  PTS  1992
# 983    STL  BLK  TOV  PF  PTS  1993
# 1451   STL  BLK  TOV  PF  PTS  1994
# 1948   STL  BLK  TOV  PF  PTS  1995
# 2421   STL  BLK  TOV  PF  PTS  1996
# 2991   STL  BLK  TOV  PF  PTS  1997
# 3589   STL  BLK  TOV  PF  PTS  1998
# 4146   STL  BLK  TOV  PF  PTS  1999
# 4673   STL  BLK  TOV  PF  PTS  2000
# 5189   STL  BLK  TOV  PF  PTS  2001
# 5751   STL  BLK  TOV  PF  PTS  2002
# 6267   STL  BLK  TOV  PF  PTS  2003
# 6780   STL  BLK  TOV  PF  PTS  2004
# 7388   STL  BLK  TOV  PF  PTS  2005
# 7993   STL  BLK  TOV  PF  PTS  2006
# 8563   STL  BLK  TOV  PF  PTS  2007
# 9108   STL  BLK  TOV  PF  PTS  2008
# 9722   STL  BLK  TOV  PF  PTS  2009
# 10322  STL  BLK  TOV  PF  PTS  2010
# 10937  STL  BLK  TOV  PF  PTS  2011
# 11564  STL  BLK  TOV  PF  PTS  2012
# 12146  STL  BLK  TOV  PF  PTS  2013
# 12744  STL  BLK  TOV  PF  PTS  2014
# 13372  STL  BLK  TOV  PF  PTS  2015
# 14042  STL  BLK  TOV  PF  PTS  2016
# 14644  STL  BLK  TOV  PF  PTS  2017
# 15262  STL  BLK  TOV  PF  PTS  2018
# 15953  STL  BLK  TOV  PF  PTS  2019
# 16690  STL  BLK  TOV  PF  PTS  2020
# 17364  STL  BLK  TOV  PF  PTS  2021
#
# [31 rows x 31 columns]

# %%
# Drop data tersebut
players_df.drop(players_df.index[players_df['Rk'] == 'Rk'], inplace = True)

# Mengecek kembali keberadaan row yang sudah di drop
wrong_value = players_df.loc[players_df['Rk'] == 'Rk']
wrong_value
# Out:
# Empty DataFrame
# Columns: [Rk, Player, Pos, Age, Tm, G, GS, MP, FG, FGA, FG%, 3P, 3PA, 3P%, 2P, 2PA, 2P%, eFG%, FT, FTA, FT%, ORB, DRB, TRB, AST, STL, BLK, TOV, PF, PTS, Year]
# Index: []
#
# [0 rows x 31 columns]

# %%
players_df["Player"] = players_df["Player"].str.replace("*", "", regex=False)

players_df["Player"] = players_df["Player"].str.replace("?", "", regex=False)

# %% [markdown]
# Dataset salaries

# %%
display_both_head_and_tail(salaries_df)
# Out:
# C:\Users\ASUS-GAMING\AppData\Local\Temp\ipykernel_16356\276291969.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return dataset.head(display_cnt).append(dataset.tail(display_cnt))
#        Unnamed: 0              Name  Year    Salaries  Rank
# 0               1  Shaquille O'Neal  2000  17142000.0     1
# 1               2     Kevin Garnett  2000  16806000.0     2
# 2               3   Alonzo Mourning  2000  15004000.0     3
# 3               4      Juwan Howard  2000  15000000.0     4
# 4               5    Scottie Pippen  2000  14795000.0     5
# 5               6       Karl Malone  2000  14000000.0     6
# 6               7     Larry Johnson  2000  11910000.0     7
# 7               8       Gary Payton  2000  11020000.0     8
# 8               9   Rasheed Wallace  2000  10800000.0     9
# 9              10        Shawn Kemp  2000  10780000.0    10
# 10             11  Damon Stoudamire  2000  10125000.0    11
# 11             12   Antonio McDyess  2000   9900000.0    12
# 12             13         Ray Allen  2000   9000000.0    14
# 13             14    Antoine Walker  2000   9000000.0    14
# 14             15   Stephon Marbury  2000   9000000.0    14
# 37405       37406       Yante Maten  2019     77250.0   487
# 37406       37407   Duncan Robinson  2019     77250.0   487
# 37407       37408      Trevon Duval  2019     77250.0   487
# 37408       37409     Jared Terrell  2019     77250.0   487
# 37409       37410    Trevon Bluiett  2019     77250.0   487
# 37410       37411     Allonzo Trier  2019     77250.0   487
# 37411       37412     Deonte Burton  2019     77250.0   487
# 37412       37413       Tyler Davis  2019     77250.0   487
# 37413       37414      Troy Caupain  2019     77250.0   487
# 37414       37415      Shake Milton  2019     77250.0   487
# 37415       37416       George King  2019     77250.0   487
# 37416       37417      Drew Eubanks  2019     77250.0   487
# 37417       37418       Jordan Loyd  2019     77250.0   487
# 37418       37419    Wenyen Gabriel  2019     75000.0   512
# 37419       37420         Nuni Omot  2019     20000.0   513

# %%
salaries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37420 entries, 0 to 37419
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  37420 non-null  int64
#  1   Name        37420 non-null  object
#  2   Year        37420 non-null  int64
#  3   Salaries    9346 non-null   float64
#  4   Rank        37420 non-null  int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ MB

# %%
print("Terdapat missing values pada dataset salaries")
cek_missing_values(salaries_df)
# Out:
# Terdapat missing values pada dataset salaries
#           Total   Percent
# Salaries  28074  0.750241

# %%
print("Missing values tersebut diisi dengan median setiap atribut")

salaries_df.Salaries.fillna(salaries_df.Salaries.median(), inplace=True)
# Out:
# Missing values tersebut diisi dengan median setiap atribut

# %%
print("Sudah tidak ada missing value pada dataset salaries")
cek_missing_values(salaries_df)
# Out:
# Sudah tidak ada missing value pada dataset salaries
# Empty DataFrame
# Columns: [Total, Percent]
# Index: []

# %% [markdown]
# Dataset teams

# %%
display_both_head_and_tail(teams_df)
# Out:
# C:\Users\ASUS-GAMING\AppData\Local\Temp\ipykernel_16356\276291969.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return dataset.head(display_cnt).append(dataset.tail(display_cnt))
#                        W                   L                W/L%  \
# 0                     56                  26                 683
# 1                     44                  38                 537
# 2                     39                  43                 476
# 3                     30                  52                 366
# 4                     26                  56                 317
# 5                     24                  58                 293
# 6       Central Division    Central Division    Central Division
# 7                     61                  21                 744
# 8                     50                  32                0.61
# 9                     48                  34                 585
# 10                    43                  39                 524
# 11                    41                  41                 0.5
# 12                    33                  49                 402
# 13                    26                  56                 317
# 14      Midwest Division    Midwest Division    Midwest Division
# 1018                  42                  30                 583
# 1019                  23                  49                 319
# 1020                  22                  50                 306
# 1021    Pacific Division    Pacific Division    Pacific Division
# 1022                  51                  21                 708
# 1023                  47                  25                 653
# 1024                  42                  30                 583
# 1025                  39                  33                 542
# 1026                  31                  41                 431
# 1027  Southwest Division  Southwest Division  Southwest Division
# 1028                  42                  30                 583
# 1029                  38                  34                 528
# 1030                  33                  39                 458
# 1031                  31                  41                 431
# 1032                  17                  55                 236
#
#                       GB                PS/G                PA/G  \
# 0                      —               111.5               105.7
# 1                     12               105.4               105.6
# 2                     17               103.1               103.3
# 3                     26               101.4               106.4
# 4                     30               102.9               107.5
# 5                     32               101.8               107.8
# 6       Central Division    Central Division    Central Division
# 7                      —                 110                 101
# 8                     11               100.1                96.8
# 9                     13               106.4                 104
# 10                    18               109.8                 109
# 11                    20               111.7               112.1
# 12                    28               101.7               104.2
# 13                    35               102.8                 108
# 14      Midwest Division    Midwest Division    Midwest Division
# 1018                  10               116.1               114.3
# 1019                  29               112.1               117.7
# 1020                  30                 105               115.6
# 1021    Pacific Division    Pacific Division    Pacific Division
# 1022                   —               115.3               109.5
# 1023                   4                 114               107.8
# 1024                   9               109.5               106.8
# 1025                  12               113.7               112.7
# 1026                  20               113.7               117.4
# 1027  Southwest Division  Southwest Division  Southwest Division
# 1028                   —               112.4               110.2
# 1029                   4               113.3               112.3
# 1030                   9               111.1               112.8
# 1031                  11               114.6               114.9
# 1032                  25               108.8               116.7
#
#                      SRS  Year                     Team
# 0                   5.22  1991          Boston Celtics*
# 1                  -0.39  1991      Philadelphia 76ers*
# 2                  -0.43  1991         New York Knicks*
# 3                  -4.84  1991       Washington Bullets
# 4                  -4.53  1991          New Jersey Nets
# 5                  -5.91  1991               Miami Heat
# 6       Central Division  1991         Central Division
# 7                   8.57  1991           Chicago Bulls*
# 8                   3.08  1991         Detroit Pistons*
# 9                   2.33  1991         Milwaukee Bucks*
# 10                  0.72  1991           Atlanta Hawks*
# 11                 -0.37  1991          Indiana Pacers*
# 12                 -2.33  1991      Cleveland Cavaliers
# 13                 -4.95  1991        Charlotte Hornets
# 14      Midwest Division  1991         Midwest Division
# 1018                1.81  2021  Portland Trail Blazers*
# 1019               -5.25  2021   Minnesota Timberwolves
# 1020              -10.13  2021    Oklahoma City Thunder
# 1021    Pacific Division  2021         Pacific Division
# 1022                5.67  2021            Phoenix Suns*
# 1023                6.02  2021    Los Angeles Clippers*
# 1024                2.77  2021      Los Angeles Lakers*
# 1025                 1.1  2021    Golden State Warriors
# 1026               -3.45  2021         Sacramento Kings
# 1027  Southwest Division  2021       Southwest Division
# 1028                2.26  2021        Dallas Mavericks*
# 1029                1.07  2021       Memphis Grizzlies*
# 1030               -1.58  2021        San Antonio Spurs
# 1031                -0.2  2021     New Orleans Pelicans
# 1032                -7.5  2021          Houston Rockets

# %%
teams_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1033 entries, 0 to 1032
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       1033 non-null   object
#  1   L       1033 non-null   object
#  2   W/L%    1033 non-null   object
#  3   GB      1033 non-null   object
#  4   PS/G    1033 non-null   object
#  5   PA/G    1033 non-null   object
#  6   SRS     1033 non-null   object
#  7   Year    1033 non-null   int64
#  8   Team    1033 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 72.8+ KB

# %%
print("Tidak ditemukan missing value pada dataset teams")
cek_missing_values(teams_df)
# Out:
# Tidak ditemukan missing value pada dataset teams
# Empty DataFrame
# Columns: [Total, Percent]
# Index: []

# %%
print("Jumlah duplikasi data pada dataset teams:", teams_df.duplicated().sum())
# Out:
# Jumlah duplikasi data pada dataset teams: 0

# %%
teams_df = teams_df[~teams_df["W"].str.contains("Division")]

teams_df["Team"] = teams_df["Team"].str.replace("*", "", regex=False)

#Menghilangkan tanda * pada nama teams

# %%
import seaborn as sb
import matplotlib.pyplot as plt

plt.figure(figsize=(30,30))

dataplot = sb.heatmap(mvps_df.corr(), cmap="YlGnBu", annot=True, )
  
# displaying heatmap
plt.show()

# %% [markdown]
# #1a. Apakah yang menjadi faktor utama (secara statistik) seorang pemain menjadi MVP?

# %%
mvps_df["is_mvp"] = ''
display(mvps_df)
# Out:
#     Rank             Player  Age   Tm  First  Pts Won  Pts Max  Share   G  \
# 0      1     Michael Jordan   27  CHI     77      891      960  928.0  82
# 1      2      Magic Johnson   31  LAL     10      497      960  518.0  79
# 2      3     David Robinson   25  SAS      6      476      960  496.0  82
# 3      4    Charles Barkley   27  PHI      2      222      960  231.0  67
# 4      5        Karl Malone   27  UTA      0      142      960  148.0  82
# ..   ...                ...  ...  ...    ...      ...      ...    ...  ..
# 469   11  Russell Westbrook   32  WAS      0        5     1010    5.0  65
# 470   12        Ben Simmons   24  PHI      0        3     1010    3.0  58
# 471  13T       James Harden   31  TOT      0        1     1010    1.0  44
# 472  13T       LeBron James   36  LAL      0        1     1010    1.0  45
# 473  13T      Kawhi Leonard   29  LAC      0        1     1010    1.0  52
#
#        MP  ...   AST  STL  BLK     FG%     3P%     FT%    WS  WS/48  Year  \
# 0    37.0  ...   5.5  2.7  1.0  539.00  312.00  851.00  20.3  321.0  1991
# 1    37.1  ...  12.5  1.3  0.2  477.00    0.32  906.00  15.4  251.0  1991
# 2    37.7  ...   2.5  1.5  3.9  552.00  143.00  762.00  17.0  264.0  1991
# 3    37.3  ...   4.2  1.6  0.5    0.57  284.00  722.00  13.4  258.0  1991
# 4    40.3  ...   3.3  1.1  1.0  527.00  286.00    0.77  15.5  225.0  1991
# ..    ...  ...   ...  ...  ...     ...     ...     ...   ...    ...   ...
# 469  36.4  ...  11.7  1.4  0.4  439.00  315.00  656.00   3.7   75.0  2021
# 470  32.4  ...   6.9  1.6  0.6  557.00    0.30  613.00   6.0  153.0  2021
# 471  36.6  ...  10.8  1.2  0.8  466.00  362.00  861.00   7.0  208.0  2021
# 472  33.4  ...   7.8  1.1  0.6  513.00  365.00  698.00   5.6  179.0  2021
# 473  34.1  ...   5.2  1.6  0.4  512.00  398.00  885.00   8.8  238.0  2021
#
#      is_mvp
# 0
# 1
# 2
# 3
# 4
# ..      ...
# 469
# 470
# 471
# 472
# 473
#
# [474 rows x 22 columns]

# %%
mvps_df.loc[mvps_df["Rank"] == "1", "is_mvp"] = 1
mvps_df.loc[mvps_df["Rank"] != "1", "is_mvp"] = 0
display(mvps_df)
# Out:
#     Rank             Player  Age   Tm  First  Pts Won  Pts Max  Share   G  \
# 0      1     Michael Jordan   27  CHI     77      891      960  928.0  82
# 1      2      Magic Johnson   31  LAL     10      497      960  518.0  79
# 2      3     David Robinson   25  SAS      6      476      960  496.0  82
# 3      4    Charles Barkley   27  PHI      2      222      960  231.0  67
# 4      5        Karl Malone   27  UTA      0      142      960  148.0  82
# ..   ...                ...  ...  ...    ...      ...      ...    ...  ..
# 469   11  Russell Westbrook   32  WAS      0        5     1010    5.0  65
# 470   12        Ben Simmons   24  PHI      0        3     1010    3.0  58
# 471  13T       James Harden   31  TOT      0        1     1010    1.0  44
# 472  13T       LeBron James   36  LAL      0        1     1010    1.0  45
# 473  13T      Kawhi Leonard   29  LAC      0        1     1010    1.0  52
#
#        MP  ...   AST  STL  BLK     FG%     3P%     FT%    WS  WS/48  Year  \
# 0    37.0  ...   5.5  2.7  1.0  539.00  312.00  851.00  20.3  321.0  1991
# 1    37.1  ...  12.5  1.3  0.2  477.00    0.32  906.00  15.4  251.0  1991
# 2    37.7  ...   2.5  1.5  3.9  552.00  143.00  762.00  17.0  264.0  1991
# 3    37.3  ...   4.2  1.6  0.5    0.57  284.00  722.00  13.4  258.0  1991
# 4    40.3  ...   3.3  1.1  1.0  527.00  286.00    0.77  15.5  225.0  1991
# ..    ...  ...   ...  ...  ...     ...     ...     ...   ...    ...   ...
# 469  36.4  ...  11.7  1.4  0.4  439.00  315.00  656.00   3.7   75.0  2021
# 470  32.4  ...   6.9  1.6  0.6  557.00    0.30  613.00   6.0  153.0  2021
# 471  36.6  ...  10.8  1.2  0.8  466.00  362.00  861.00   7.0  208.0  2021
# 472  33.4  ...   7.8  1.1  0.6  513.00  365.00  698.00   5.6  179.0  2021
# 473  34.1  ...   5.2  1.6  0.4  512.00  398.00  885.00   8.8  238.0  2021
#
#      is_mvp
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 469       0
# 470       0
# 471       0
# 472       0
# 473       0
#
# [474 rows x 22 columns]

# %%
arr_init_name = nicknames_df['Abbreviation'].values

for i in arr_init_name : 
    val_real_team_name = nicknames_df['Name'].loc[nicknames_df['Abbreviation'] == i].values
    mvps_df.loc[mvps_df["Tm"] == i, "Tm"] = val_real_team_name[0]

display(mvps_df)

mvps_df.rename(columns = {'Tm':'Team'}, inplace = True)
# Out:
#     Rank             Player  Age                    Tm  First  Pts Won  \
# 0      1     Michael Jordan   27         Chicago Bulls     77      891
# 1      2      Magic Johnson   31    Los Angeles Lakers     10      497
# 2      3     David Robinson   25     San Antonio Spurs      6      476
# 3      4    Charles Barkley   27    Philadelphia 76ers      2      222
# 4      5        Karl Malone   27             Utah Jazz      0      142
# ..   ...                ...  ...                   ...    ...      ...
# 469   11  Russell Westbrook   32    Washington Wizards      0        5
# 470   12        Ben Simmons   24    Philadelphia 76ers      0        3
# 471  13T       James Harden   31                   TOT      0        1
# 472  13T       LeBron James   36    Los Angeles Lakers      0        1
# 473  13T      Kawhi Leonard   29  Los Angeles Clippers      0        1
#
#      Pts Max  Share   G    MP  ...   AST  STL  BLK     FG%     3P%     FT%  \
# 0        960  928.0  82  37.0  ...   5.5  2.7  1.0  539.00  312.00  851.00
# 1        960  518.0  79  37.1  ...  12.5  1.3  0.2  477.00    0.32  906.00
# 2        960  496.0  82  37.7  ...   2.5  1.5  3.9  552.00  143.00  762.00
# 3        960  231.0  67  37.3  ...   4.2  1.6  0.5    0.57  284.00  722.00
# 4        960  148.0  82  40.3  ...   3.3  1.1  1.0  527.00  286.00    0.77
# ..       ...    ...  ..   ...  ...   ...  ...  ...     ...     ...     ...
# 469     1010    5.0  65  36.4  ...  11.7  1.4  0.4  439.00  315.00  656.00
# 470     1010    3.0  58  32.4  ...   6.9  1.6  0.6  557.00    0.30  613.00
# 471     1010    1.0  44  36.6  ...  10.8  1.2  0.8  466.00  362.00  861.00
# 472     1010    1.0  45  33.4  ...   7.8  1.1  0.6  513.00  365.00  698.00
# 473     1010    1.0  52  34.1  ...   5.2  1.6  0.4  512.00  398.00  885.00
#
#        WS  WS/48  Year  is_mvp
# 0    20.3  321.0  1991       1
# 1    15.4  251.0  1991       0
# 2    17.0  264.0  1991       0
# 3    13.4  258.0  1991       0
# 4    15.5  225.0  1991       0
# ..    ...    ...   ...     ...
# 469   3.7   75.0  2021       0
# 470   6.0  153.0  2021       0
# 471   7.0  208.0  2021       0
# 472   5.6  179.0  2021       0
# 473   8.8  238.0  2021       0
#
# [474 rows x 22 columns]

# %%
teams_col = teams_df.columns
for i in teams_col :
    if i != "Team" :
        teams_df[i] = pd.to_numeric(teams_df[i], errors='coerce')

temp_teams = teams_df.groupby("Year").mean().reset_index()
year = temp_teams['Year'].values

d = {"score" : []}
temp_pd = pd.DataFrame(data = d)
for i in year :
    val =  temp_teams['GB'].loc[temp_teams['Year'] == i].values
    temp = teams_df['GB'].loc[teams_df["Year"] == i].fillna(val[0])
    temp_pd = pd.concat([temp_pd, temp])

# del temp_pd["score"]
teams_df["GB"] = temp_pd[0]
display(teams_df)
# Out:
#        W   L   W/L%         GB   PS/G   PA/G   SRS  Year                  Team
# 0     56  26  683.0  20.956522  111.5  105.7  5.22  1991        Boston Celtics
# 1     44  38  537.0  12.000000  105.4  105.6 -0.39  1991    Philadelphia 76ers
# 2     39  43  476.0  17.000000  103.1  103.3 -0.43  1991       New York Knicks
# 3     30  52  366.0  26.000000  101.4  106.4 -4.84  1991    Washington Bullets
# 4     26  56  317.0  30.000000  102.9  107.5 -4.53  1991       New Jersey Nets
# ...   ..  ..    ...        ...    ...    ...   ...   ...                   ...
# 1028  42  30  583.0  13.541667  112.4  110.2  2.26  2021      Dallas Mavericks
# 1029  38  34  528.0   4.000000  113.3  112.3  1.07  2021     Memphis Grizzlies
# 1030  33  39  458.0   9.000000  111.1  112.8 -1.58  2021     San Antonio Spurs
# 1031  31  41  431.0  11.000000  114.6  114.9 -0.20  2021  New Orleans Pelicans
# 1032  17  55  236.0  25.000000  108.8  116.7 -7.50  2021       Houston Rockets
#
# [906 rows x 9 columns]

# %%
mvps_and_teams = mvps_df.merge(teams_df, on=['Team','Year'])
display(mvps_and_teams)
# Out:
#     Rank             Player  Age                  Team  First  Pts Won  \
# 0      1     Michael Jordan   27         Chicago Bulls     77      891
# 1      2      Magic Johnson   31    Los Angeles Lakers     10      497
# 2      3     David Robinson   25     San Antonio Spurs      6      476
# 3      4    Charles Barkley   27    Philadelphia 76ers      2      222
# 4      5        Karl Malone   27             Utah Jazz      0      142
# ..   ...                ...  ...                   ...    ...      ...
# 462    8      Julius Randle   26       New York Knicks      0       20
# 463   10        Rudy Gobert   28             Utah Jazz      0        8
# 464   11  Russell Westbrook   32    Washington Wizards      0        5
# 465  13T       LeBron James   36    Los Angeles Lakers      0        1
# 466  13T      Kawhi Leonard   29  Los Angeles Clippers      0        1
#
#      Pts Max   Share   G    MP  ...   WS/48  Year  is_mvp   W   L   W/L%  \
# 0        960  928.00  82  37.0  ...  321.00  1991       1  61  21  744.0
# 1        960  518.00  79  37.1  ...  251.00  1991       0  58  24  707.0
# 2        960  496.00  82  37.7  ...  264.00  1991       0  55  27  671.0
# 3        960  231.00  67  37.3  ...  258.00  1991       0  44  38  537.0
# 4        960  148.00  82  40.3  ...  225.00  1991       0  54  28  659.0
# ..       ...     ...  ..   ...  ...     ...   ...     ...  ..  ..    ...
# 462     1010    0.02  71  37.6  ...    0.14  2021       0  41  31  569.0
# 463     1010    8.00  71  30.8  ...  248.00  2021       0  52  20  722.0
# 464     1010    5.00  65  36.4  ...   75.00  2021       0  34  38  472.0
# 465     1010    1.00  45  33.4  ...  179.00  2021       0  42  30  583.0
# 466     1010    1.00  52  34.1  ...  238.00  2021       0  47  25  653.0
#
#             GB   PS/G   PA/G   SRS
# 0    20.956522  110.0  101.0  8.57
# 1     5.000000  106.3   99.6  6.73
# 2    20.956522  107.1  102.6  4.30
# 3    12.000000  105.4  105.6 -0.39
# 4     1.000000  104.0  100.7  3.18
# ..         ...    ...    ...   ...
# 462   8.000000  107.0  104.7  2.13
# 463  13.541667  116.4  107.2  8.97
# 464   7.000000  116.6  118.5 -1.85
# 465   9.000000  109.5  106.8  2.77
# 466   4.000000  114.0  107.8  6.02
#
# [467 rows x 29 columns]

# %%
col = mvps_and_teams.columns

for i in col :
    if i != "Rank" and i != "Player" and i != "Team" and i != "is_mvp" :
        mvps_and_teams[i] = pd.to_numeric(mvps_and_teams[i])

mvps_and_teams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 467 entries, 0 to 466
# Data columns (total 29 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     467 non-null    object
#  1   Player   467 non-null    object
#  2   Age      467 non-null    int64
#  3   Team     467 non-null    object
#  4   First    467 non-null    int64
#  5   Pts Won  467 non-null    int64
#  6   Pts Max  467 non-null    int64
#  7   Share    467 non-null    float64
#  8   G        467 non-null    int64
#  9   MP       467 non-null    float64
#  10  PTS      467 non-null    float64
#  11  TRB      467 non-null    float64
#  12  AST      467 non-null    float64
#  13  STL      467 non-null    float64
#  14  BLK      467 non-null    float64
#  15  FG%      467 non-null    float64
#  16  3P%      467 non-null    float64
#  17  FT%      467 non-null    float64
#  18  WS       467 non-null    float64
#  19  WS/48    467 non-null    float64
#  20  Year     467 non-null    int64
#  21  is_mvp   467 non-null    object
#  22  W        467 non-null    int64
#  23  L        467 non-null    int64
#  24  W/L%     467 non-null    float64
#  25  GB       467 non-null    float64
#  26  PS/G     467 non-null    float64
#  27  PA/G     467 non-null    float64
#  28  SRS      467 non-null    float64
# dtypes: float64(17), int64(8), object(4)
# memory usage: 109.5+ KB

# %%
X_raw = mvps_and_teams.drop(["Rank", "Player", "Team"],axis=1)
lst_column = X_raw.columns
y = mvps_and_teams["is_mvp"]
X_raw = X_raw.drop(["is_mvp"],axis=1)

display(lst_column)
# Out:
# Index(['Age', 'First', 'Pts Won', 'Pts Max', 'Share', 'G', 'MP', 'PTS', 'TRB',
#        'AST', 'STL', 'BLK', 'FG%', '3P%', 'FT%', 'WS', 'WS/48', 'Year',
#        'is_mvp', 'W', 'L', 'W/L%', 'GB', 'PS/G', 'PA/G', 'SRS'],
#       dtype='object')

# %%
from scipy.stats import pearsonr

for i in lst_column :
    if i != "is_mvp" :
        corr, _ = pearsonr(mvps_and_teams[i], mvps_and_teams["is_mvp"])
        if corr > 0.1 :
            print(i + " : " + str(corr))
# Out:
# First : 0.9217981829015235
# Pts Won : 0.7120673799647419
# Share : 0.6708995401575366
# PTS : 0.2512041440039777
# WS : 0.3922461508985588
# WS/48 : 0.2779454293078143
# W : 0.25076225864874346
# W/L% : 0.11227508768540669
# GB : 0.1501843906437084
# SRS : 0.2557466449068887

# %% [markdown]
# Dengan melihat korelasi di atas diketahui bahwa terdapat 10 variable yang dapat menjadi faktor pemain menjadi MVP, yaitu First, Pts Won, Share, PTS, WS, WS/48, Win dari teamnya pada tahun itu, W/L% dari teamnya pada tahun itu, GB dari teamnya pada tahun itu, dan SRS dari teamnya pada tahun itu

# %%
rank_one = mvps_df.loc[mvps_df['Rank'] == '1']
display(rank_one.head())
# Out:
#    Rank           Player  Age               Team  First  Pts Won  Pts Max  \
# 0     1   Michael Jordan   27      Chicago Bulls     77      891      960
# 20    1   Michael Jordan   28      Chicago Bulls     80      900      960
# 37    1  Charles Barkley   29       Phoenix Suns     59      835      980
# 51    1  Hakeem Olajuwon   31    Houston Rockets     66      889     1010
# 68    1   David Robinson   29  San Antonio Spurs     73      901     1050
#
#      Share   G    MP  ...  AST  STL  BLK     FG%     3P%    FT%    WS   WS/48  \
# 0   928.00  82  37.0  ...  5.5  2.7  1.0  539.00  312.00  851.0  20.3  321.00
# 20  938.00  80  38.8  ...  6.1  2.3  0.9  519.00    0.27  832.0  17.7  274.00
# 37  852.00  76  37.6  ...  5.1  1.6  1.0    0.52  305.00  765.0  14.4  242.00
# 51    0.88  80  41.0  ...  3.6  1.6  3.7  528.00  421.00  716.0  14.3    0.21
# 68  858.00  81  38.0  ...  2.9  1.7  3.2    0.53    0.30  774.0  17.5  273.00
#
#     Year  is_mvp
# 0   1991       1
# 20  1992       1
# 37  1993       1
# 51  1994       1
# 68  1995       1
#
# [5 rows x 22 columns]

# %%
rank_one[['First', 'Pts Won', 'Share', 'PTS', 'WS', 'WS/48']].describe()
# Out:
#             First      Pts Won       Share        PTS         WS       WS/48
# count   31.000000    31.000000   31.000000  31.000000  31.000000   31.000000
# mean    87.161290  1045.967742  815.060000  27.158065  15.845161  254.109677
# std     23.395294   137.332804  281.320447   3.692946   2.955203   76.386628
# min     44.000000   827.000000    0.880000  15.500000   9.600000    0.190000
# 25%     67.500000   932.500000  845.500000  25.250000  14.050000  240.000000
# 50%     85.000000  1066.000000  904.000000  27.600000  15.800000  274.000000
# 75%    109.000000  1177.000000  958.000000  29.900000  18.100000  296.500000
# max    131.000000  1310.000000  998.000000  32.000000  20.400000  322.000000

# %% [markdown]
# #1b. Apakah terdapat kenaikan rata-rata gaji pemain dari tahun 2000 - 2019?

# %%
df_salaries_year = salaries_df.groupby("Year")["Salaries"].mean().reset_index()
df_salaries_year = df_salaries_year.astype({"Year":'category'})

# %%
axes = plt.gca()
df_salaries_year.set_index('Year', inplace=True)
df_salaries_year.plot(kind="line", y="Salaries", ax=axes)
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# Dengan melihat grafik di atas diketahui bahwa secara garis besar terdapat perumbuhan gaji dari 2000 - 2019. Pertumbuhan gaji naik secara signifikan pada rentang 2015 - 2019. Namun, seperti yang kita ketahui nilai dari mata uang mengalami inflasi dari setiap tahunnya sehingga kita perlu membandingkan nilai pada tahun selain 2019 dengan tahun 2019. Pada kali ini saya menggunakan dataset harga persentase dolar dengan tahun 2019. Sumber data berasal dari https://www.in2013dollars.com/us/inflation/2003

# %%
inflation_df = pd.read_excel("datasets/persentase_dolar_2000_2019.xlsx")

inflation_df = inflation_df.astype({"Year":'category'})

axes = plt.gca()
inflation_df.set_index('Year', inplace=True)
inflation_df.plot(kind="line", y="Percentage", ax=axes)
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# Dari grafik di atas diketahui terdapat penurunan nilai, sehingga secara garis besar setaip tahun mengalami penurunan nilai mata uang (inflasi). Dengan demikina kita perlu mengetahui nilai asli salaries sesuai dengan tahun 2019

# %%
salaries_df_update = df_salaries_year.merge(inflation_df, on="Year").reset_index()

salaries_df_update["Real Salaries"] = salaries_df_update["Salaries"] * salaries_df_update["Percentage"]

axes = plt.gca()
salaries_df_update.set_index('Year', inplace=True)
salaries_df_update.plot(kind="line", y="Real Salaries", ax=axes)
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# Dari visualisasi di atas diketahui bahwa rata-rata gaji pemain pada tahun 2019 lebih kecil dibanding tahun 2000. Lalu, terjadi penurunan rata-rata gaji pemain dari rentang tahun 2000 - 2014 dan rata-rata gaji pemain mulai kembali naik pada rentang 2014-2019

# %% [markdown]
# #1c. Apakah kemenangan dari suatu tim dapat dikorelasikan dengan suatu variabel tertentu?

# %%
display(teams_df.head())
# Out:
#     W   L   W/L%         GB   PS/G   PA/G   SRS  Year                Team
# 0  56  26  683.0  20.956522  111.5  105.7  5.22  1991      Boston Celtics
# 1  44  38  537.0  12.000000  105.4  105.6 -0.39  1991  Philadelphia 76ers
# 2  39  43  476.0  17.000000  103.1  103.3 -0.43  1991     New York Knicks
# 3  30  52  366.0  26.000000  101.4  106.4 -4.84  1991  Washington Bullets
# 4  26  56  317.0  30.000000  102.9  107.5 -4.53  1991     New Jersey Nets

# %%
display(players_df)
# Out:
#         Rk              Player Pos Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0        1      Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3   2.7  ...
# 1        2  Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2  15.1  ...
# 2        3          Mark Acres   C  28  ORL  68   0  19.3  1.6   3.1  ...
# 3        4       Michael Adams  PG  28  DEN  66  66  35.5  8.5  21.5  ...
# 4        5        Mark Aguirre  SF  31  DET  78  13  25.7  5.4  11.7  ...
# ...    ...                 ...  ..  ..  ...  ..  ..   ...  ...   ...  ...
# 18039  536        Delon Wright  PG  28  SAC  27   8  25.8  3.9   8.3  ...
# 18040  537      Thaddeus Young  PF  32  CHI  68  23  24.3  5.4   9.7  ...
# 18041  538          Trae Young  PG  22  ATL  63  63  33.7  7.7  17.7  ...
# 18042  539         Cody Zeller   C  28  CHO  48  21  20.9  3.8   6.8  ...
# 18043  540         Ivica Zubac   C  23  LAC  72  33  22.3  3.6   5.5  ...
#
#        ORB  DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Year
# 0      0.6  1.4  2.1   0.3  0.1  0.3  0.5  0.9   3.1  1991
# 1      0.5  1.3  1.8   3.1  0.8  0.1  1.6  2.2  14.1  1991
# 2      2.1  3.2  5.3   0.4  0.4  0.4  0.6  3.2   4.2  1991
# 3      0.9    3  3.9  10.5  2.2  0.1  3.6  2.5  26.5  1991
# 4      1.7  3.1  4.8   1.8  0.6  0.3  1.6  2.7  14.2  1991
# ...    ...  ...  ...   ...  ...  ...  ...  ...   ...   ...
# 18039    1  2.9  3.9   3.6  1.6  0.4  1.3  1.1    10  2021
# 18040  2.5  3.8  6.2   4.3  1.1  0.6    2  2.2  12.1  2021
# 18041  0.6  3.3  3.9   9.4  0.8  0.2  4.1  1.8  25.3  2021
# 18042  2.5  4.4  6.8   1.8  0.6  0.4  1.1  2.5   9.4  2021
# 18043  2.6  4.6  7.2   1.3  0.3  0.9  1.1  2.6     9  2021
#
# [17386 rows x 31 columns]

# %%
temp_player_df = players_df.copy()
temp_player_df = temp_player_df.drop(["Rk", "Player", "Pos"],axis=1)
lst_column_temp_player = temp_player_df.columns


for i in lst_column_temp_player :
    if i != "Tm" :
        temp_player_df[i] = pd.to_numeric(temp_player_df[i], errors='coerce')

# %%
data_player_groupby_team_and_year = temp_player_df.groupby(['Tm','Year']).mean().reset_index()
display(data_player_groupby_team_and_year.head())
# Out:
#     Tm  Year        Age          G         GS         MP        FG       FGA  \
# 0  ATL  1991  27.357143  59.928571  29.285714  19.442857  3.200000  6.935714
# 1  ATL  1992  26.600000  54.600000  27.333333  21.120000  3.773333  8.126667
# 2  ATL  1993  27.058824  49.235294  24.117647  18.529412  2.976471  6.558824
# 3  ATL  1994  28.133333  54.933333  27.333333  20.113333  3.406667  7.460000
# 4  ATL  1995  28.777778  45.833333  22.777778  19.144444  2.827778  6.544444
#
#           FG%        3P  ...         FT%       ORB       DRB       TRB  \
# 0  381.340714  0.242857  ...  599.428571  1.171429  2.428571  3.600000
# 1  465.800000  0.333333  ...  529.430000  1.320000  2.466667  3.786667
# 2  313.574118  0.347059  ...  421.231176  1.194118  2.164706  3.358824
# 3  399.367333  0.246667  ...  531.097333  1.233333  2.426667  3.660000
# 4  328.299444  0.438889  ...  537.312222  1.150000  2.588889  3.727778
#
#         AST       STL       BLK       TOV        PF       PTS
# 0  1.814286  0.714286  0.371429  1.221429  1.785714  8.628571
# 1  2.213333  0.806667  0.326667  1.326667  1.913333  9.526667
# 2  1.870588  0.776471  0.282353  1.235294  1.852941  7.694118
# 3  2.040000  0.893333  0.440000  1.260000  1.740000  8.706667
# 4  1.672222  0.666667  0.405556  1.238889  1.805556  7.544444
#
# [5 rows x 28 columns]

# %%
arr_init_name = nicknames_df['Abbreviation'].values

for i in arr_init_name : 
    val_real_team_name = nicknames_df['Name'].loc[nicknames_df['Abbreviation'] == i].values
    data_player_groupby_team_and_year.loc[data_player_groupby_team_and_year["Tm"] == i, "Tm"] = val_real_team_name[0]

# %%
data_player_groupby_team_and_year.rename(columns = {'Tm':'Team' }, inplace = True)

# %%
new_data = pd.merge(data_player_groupby_team_and_year, teams_df)

# %%
lst_column = new_data.columns

for i in lst_column :
    if i != "Team" and i != "Year" and i != "W":
        corr, _ = pearsonr(new_data[i], new_data["W"])
        if corr > 0.1 :
            print(i + " : " + str(corr))
# Out:
# Age : 0.442802069649119
# G : 0.3996209399493923
# GS : 0.365175035754813
# FG% : 0.12783300867285402
# 3P% : 0.12018030872938014
# 2P% : 0.10292221361507631
# eFG% : 0.11459375970752972
# W/L% : 0.5924524173603722
# PS/G : 0.32807662283848504
# SRS : 0.9321367483883654

# %% [markdown]
# Dari hasil menggabungkan teams dan playerdata yang akhirnya mendapatkan banyak variable penilaian. Setelah dicek variable-variable yang ada dengan jumlah kemenangannya diketahui bahwa yang memiliki korelasi paling tinggi adalah dengan jumlah kemenangan adalah SRS (Simple Rating System). Namun, seperti yang kita ketahui bahwa SRS didapatkan dari persentase kemanangannya. Apabila dilihat dari komposisi pemainya beberapa varaibel yang bisa dijadikan acuan adalah  PS/G (passing per game), G (Game played), GS (Game started), FG% (Field Goal Percentage), 3P% (3 Point Field Goal Percentage), 2P% (2 Point Field Goal Percentage) dan eFG% (Effective Field Goal Percentage)

# %%
new_data['W/L%'] = new_data['W']/(new_data['W']+new_data['L'])*100
new_data['W-L%'] = abs(new_data['W']-new_data['L'])/abs(new_data['W']+new_data['L'])*100
new_data['W-L'] = abs(new_data['W']-new_data['L'])
display(new_data['W/L%'])
# new_data.to_excel("new_data.xlsx")
display(new_data)
# Out:
# 0      52.439024
# 1      46.341463
# 2      52.439024
# 3      69.512195
# 4      51.219512
#          ...
# 901    26.829268
# 902    29.268293
# 903    25.609756
# 904    47.560976
# 905    53.658537
# Name: W/L%, Length: 906, dtype: float64
#                    Team  Year        Age          G         GS         MP  \
# 0         Atlanta Hawks  1991  27.357143  59.928571  29.285714  19.442857
# 1         Atlanta Hawks  1992  26.600000  54.600000  27.333333  21.120000
# 2         Atlanta Hawks  1993  27.058824  49.235294  24.117647  18.529412
# 3         Atlanta Hawks  1994  28.133333  54.933333  27.333333  20.113333
# 4         Atlanta Hawks  1995  28.777778  45.833333  22.777778  19.144444
# ..                  ...   ...        ...        ...        ...        ...
# 901  Washington Bullets  1993  26.052632  43.947368  21.578947  18.515789
# 902  Washington Bullets  1994  26.500000  42.300000  20.500000  18.350000
# 903  Washington Bullets  1995  25.187500  50.437500  25.625000  23.550000
# 904  Washington Bullets  1996  26.190476  39.142857  19.523810  18.695238
# 905  Washington Bullets  1997  26.266667  54.000000  27.333333  19.133333
#
#            FG       FGA         FG%        3P  ...       PTS   W   L  \
# 0    3.200000  6.935714  381.340714  0.242857  ...  8.628571  43  39
# 1    3.773333  8.126667  465.800000  0.333333  ...  9.526667  38  44
# 2    2.976471  6.558824  313.574118  0.347059  ...  7.694118  43  39
# 3    3.406667  7.460000  399.367333  0.246667  ...  8.706667  57  25
# 4    2.827778  6.544444  328.299444  0.438889  ...  7.544444  42  40
# ..        ...       ...         ...       ...  ...       ...  ..  ..
# 901  3.157895  6.694737  335.844211  0.163158  ...  7.947368  22  60
# 902  2.750000  5.965000  386.773500  0.205000  ...  7.220000  24  58
# 903  3.675000  8.125000  417.160000  0.475000  ...  9.675000  21  61
# 904  2.990476  6.404762  400.695238  0.509524  ...  7.957143  39  43
# 905  2.973333  6.273333  414.353333  0.313333  ...  7.466667  44  38
#
#           W/L%         GB   PS/G   PA/G   SRS       W-L%  W-L
# 0    52.439024  18.000000  109.8  109.0  0.72   4.878049    4
# 1    46.341463  29.000000  106.2  107.7 -1.15   7.317073    6
# 2    52.439024  14.000000  107.5  108.4 -0.67   4.878049    4
# 3    69.512195  20.869565  101.4   96.2  4.94  39.024390   32
# 4    51.219512  10.000000   96.6   95.3  1.06   2.439024    2
# ..         ...        ...    ...    ...   ...        ...  ...
# 901  26.829268  38.000000  101.9  108.9 -6.49  46.341463   38
# 902  29.268293  33.000000  100.4  107.7 -7.13  41.463415   34
# 903  25.609756  36.000000  100.5  106.1 -5.56  48.780488   40
# 904  47.560976  21.000000  102.5  101.5  0.99   4.878049    4
# 905  53.658537  17.000000   99.4   97.7  1.77   7.317073    6
#
# [906 rows x 37 columns]

# %%
new_data_three = new_data.groupby('Year')['W-L%'].mean().reset_index()

display(new_data_three[new_data_three['W-L%'] == new_data_three['W-L%'].min()])
# Out:
#     Year       W-L%
# 16  2007  20.813008

# %%
from scipy.stats import skew

lst_year = new_data["Year"].unique()

lst_skew_score = []

for i in lst_year :
    temp_df = new_data.loc[new_data["Year"] == i]
    skew_score = skew(temp_df["W/L%"])
    lst_skew_score.append(skew_score)
    


for i in range(len(lst_skew_score)) :
    lst_skew_score[i] = abs(lst_skew_score[i])
min_score = min(lst_skew_score)
print(lst_skew_score)

idx = lst_skew_score.index(min_score)

print("Tahun paling kompetitif adalah " + str(lst_year[idx]))
# Out:
# [0.07716440624995054, 0.16836370581992618, 0.44326330792503504, 0.362312259743163, 0.12378828998138366, 0.11782725003664143, 0.06781080148054061, 0.38774908029761135, 0.4955958890149415, 0.2907658947959111, 0.6094591791625882, 0.11997063147455612, 0.41594802501754585, 0.055668607913878204, 0.4040247050137291, 0.24790574163071116, 0.4500548510104214, 0.18485843020472792, 0.0001498051363058389, 0.45934880303349956, 0.16304435928956895, 0.3588766778390481, 0.08662079507532693, 0.28504857128434535, 0.2381824119054705, 0.010379300771387316, 0.23906836964688033, 0.12805403413205527, 0.4207633482802097, 0.048353206880945916, 0.24917365866927313]
# Tahun paling kompetitif adalah 2009

# %%
import matplotlib.pyplot as plt

temp_df = new_data.loc[new_data["Year"] == 2009]
temp_df["W/L%"].plot.density(color='green')
plt.title('Density of Win Rate in 2009')
plt.show()

# %% [markdown]
# Dengan melihat evaluasi di atas, didapatkan lah bahwa 2009 memiliki tahun yang paling kompetitif karena dengan melihat persebaran nilai win rate dengan menggunakan skewnessnya

# %%
lst_column_temp_player = players_df.columns

for i in lst_column_temp_player :
    if i != "Tm" and i != "Rk" and i != "Player" and i != "Pos":
        players_df[i] = pd.to_numeric(players_df[i], errors='coerce')

# %% [markdown]
# Referensi game score : https://www.basketball-reference.com/about/glossary.html#pts

# %%
players_df["Avg GameScore"] = players_df["PTS"] + (0.4 * players_df["FG"]) - (0.7 * players_df["FGA"]) - (0.4*(players_df["FTA"] - players_df["FT"])) + (0.7 * players_df["ORB"]) + (0.3 * players_df["DRB"]) + players_df["STL"] + (0.7* players_df["AST"]) + (0.7* players_df["BLK"]) - (0.4* players_df["PF"]) - players_df["TOV"]

# %%
avg_age_and_gamescore = players_df.groupby("Age")["Avg GameScore"].mean().reset_index()

display(avg_age_and_gamescore[avg_age_and_gamescore["Avg GameScore"] == avg_age_and_gamescore["Avg GameScore"].max()])
# Out:
#     Age  Avg GameScore
# 10   28       6.945052

# %% [markdown]
# Dengan mempertimbangkan nilai Gamescorenya, umur golden age adalah 28 tahun dengan melihat rata-rata gamescore terbesar

# %%
for i in arr_init_name : 
    val_real_team_name = nicknames_df['Name'].loc[nicknames_df['Abbreviation'] == i].values
    players_df.loc[players_df["Tm"] == i, "Tm"] = val_real_team_name[0]

display(players_df)
# Out:
#         Rk              Player Pos  Age                      Tm   G  GS    MP  \
# 0        1      Alaa Abdelnaby  PF   22  Portland Trail Blazers  43   0   6.7
# 1        2  Mahmoud Abdul-Rauf  PG   21          Denver Nuggets  67  19  22.5
# 2        3          Mark Acres   C   28           Orlando Magic  68   0  19.3
# 3        4       Michael Adams  PG   28          Denver Nuggets  66  66  35.5
# 4        5        Mark Aguirre  SF   31         Detroit Pistons  78  13  25.7
# ...    ...                 ...  ..  ...                     ...  ..  ..   ...
# 18039  536        Delon Wright  PG   28        Sacramento Kings  27   8  25.8
# 18040  537      Thaddeus Young  PF   32           Chicago Bulls  68  23  24.3
# 18041  538          Trae Young  PG   22           Atlanta Hawks  63  63  33.7
# 18042  539         Cody Zeller   C   28       Charlotte Hornets  48  21  20.9
# 18043  540         Ivica Zubac   C   23    Los Angeles Clippers  72  33  22.3
#
#         FG   FGA  ...  DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Year  \
# 0      1.3   2.7  ...  1.4  2.1   0.3  0.1  0.3  0.5  0.9   3.1  1991
# 1      6.2  15.1  ...  1.3  1.8   3.1  0.8  0.1  1.6  2.2  14.1  1991
# 2      1.6   3.1  ...  3.2  5.3   0.4  0.4  0.4  0.6  3.2   4.2  1991
# 3      8.5  21.5  ...  3.0  3.9  10.5  2.2  0.1  3.6  2.5  26.5  1991
# 4      5.4  11.7  ...  3.1  4.8   1.8  0.6  0.3  1.6  2.7  14.2  1991
# ...    ...   ...  ...  ...  ...   ...  ...  ...  ...  ...   ...   ...
# 18039  3.9   8.3  ...  2.9  3.9   3.6  1.6  0.4  1.3  1.1  10.0  2021
# 18040  5.4   9.7  ...  3.8  6.2   4.3  1.1  0.6  2.0  2.2  12.1  2021
# 18041  7.7  17.7  ...  3.3  3.9   9.4  0.8  0.2  4.1  1.8  25.3  2021
# 18042  3.8   6.8  ...  4.4  6.8   1.8  0.6  0.4  1.1  2.5   9.4  2021
# 18043  3.6   5.5  ...  4.6  7.2   1.3  0.3  0.9  1.1  2.6   9.0  2021
#
#        Avg GameScore
# 0               2.07
# 1               7.23
# 2               3.98
# 3              21.00
# 4               9.28
# ...              ...
# 18039           9.90
# 18040          11.73
# 18041          19.70
# 18042           8.99
# 18043           9.29
#
# [17386 rows x 32 columns]

# %%
the_best_player_from_team_each_year = players_df.groupby(["Tm","Year"]).agg({"Avg GameScore" : max}).reset_index()
the_best_player_from_team_each_year = the_best_player_from_team_each_year.merge(players_df, on=["Tm", "Year", "Avg GameScore"], how="inner")

display(the_best_player_from_team_each_year)
# Out:
#                      Tm  Year  Avg GameScore   Rk             Player Pos  Age  \
# 0         Atlanta Hawks  1991          20.17  361  Dominique Wilkins  SF   31
# 1         Atlanta Hawks  1992          20.11  369  Dominique Wilkins  SF   32
# 2         Atlanta Hawks  1993          21.21  366  Dominique Wilkins  SF   33
# 3         Atlanta Hawks  1994          16.20  380  Dominique Wilkins  SF   34
# 4         Atlanta Hawks  1995          15.34   30    Mookie Blaylock  PG   27
# ..                  ...   ...            ...  ...                ...  ..  ...
# 933  Washington Wizards  2017          19.61  453          John Wall  PG   26
# 934  Washington Wizards  2018          15.72   37       Bradley Beal  SG   24
# 935  Washington Wizards  2019          19.12   40       Bradley Beal  SG   25
# 936  Washington Wizards  2020          21.24   35       Bradley Beal  SG   26
# 937  Washington Wizards  2021          21.75   38       Bradley Beal  SG   27
#
#       G  GS    MP  ...    FT%  ORB  DRB  TRB   AST  STL  BLK  TOV   PF   PTS
# 0    81  81  38.0  ...  829.0  3.2  5.8  9.0   3.3  1.5  0.8  2.5  1.9  25.9
# 1    42  42  38.1  ...  835.0  2.5  4.6  7.0   3.8  1.2  0.6  2.9  1.8  28.1
# 2    71  70  37.3  ...  828.0  2.6  4.2  6.8   3.2  1.0  0.4  2.6  1.6  29.9
# 3    49  49  34.4  ...  854.0  2.4  3.8  6.2   2.3  1.3  0.4  2.4  1.8  24.4
# 4    80  80  38.4  ...  729.0  1.5  3.5  4.9   7.7  2.5  0.3  3.0  2.1  17.2
# ..   ..  ..   ...  ...    ...  ...  ...  ...   ...  ...  ...  ...  ...   ...
# 933  78  78  36.4  ...  801.0  0.8  3.4  4.2  10.7  2.0  0.6  4.1  1.9  23.1
# 934  82  82  36.3  ...  791.0  0.7  3.7  4.4   4.5  1.2  0.4  2.6  2.0  22.6
# 935  82  82  36.9  ...  808.0  1.1  3.9  5.0   5.5  1.5  0.7  2.7  2.8  25.6
# 936  57  57  36.0  ...  842.0  0.9  3.3  4.2   6.1  1.2  0.4  3.4  2.2  30.5
# 937  60  60  35.8  ...  889.0  1.2  3.5  4.7   4.4  1.2  0.4  3.1  2.3  31.3
#
# [938 rows x 32 columns]
