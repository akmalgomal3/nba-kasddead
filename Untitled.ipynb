# %%
import numpy as np
import pandas as pd

# %%
pw_avg_gamescore_df = pd.read_csv("datasets/player_with_avg_gamescore.csv")
final_salaries_df = pd.read_csv("datasets/final_salaries.csv")

# %%
# ambil player dari tahun 2000-2019
pw_avg_gamescore_df = pw_avg_gamescore_df.loc[(pw_avg_gamescore_df['Year'] >= 2000) & (pw_avg_gamescore_df['Year'] <= 2019)]

# merge player_with_avg_gamescore dan final_salaries
combined_data_df = pw_avg_gamescore_df.merge(final_salaries_df, left_on=["Player", "Year"], 
                                             right_on=["Name", "Year"])
combined_data_df

combined_data_df[combined_data_df['Name'] == 'Tariq Abdul-Wahad']
# Out:
#       Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  STL  \
# 0      1  Tariq Abdul-Wahad  SG   25  TOT  61  56  25.9  4.5  10.6  ...  1.0
# 1      1  Tariq Abdul-Wahad  SG   25  ORL  46  46  26.2  4.8  11.2  ...  1.2
# 2      1  Tariq Abdul-Wahad  SG   25  DEN  15  10  24.9  3.4   8.7  ...  0.4
# 404    2  Tariq Abdul-Wahad  SG   26  DEN  29  12  14.5  1.5   3.8  ...  0.5
# 895    1  Tariq Abdul-Wahad  SG   27  TOT  24  12  18.4  2.3   6.1  ...  0.8
# 896    1  Tariq Abdul-Wahad  SG   27  DEN  20  12  20.9  2.8   7.3  ...  0.9
# 897    1  Tariq Abdul-Wahad  SG   27  DAL   4   0   6.0  0.0   0.5  ...  0.5
# 1371   1  Tariq Abdul-Wahad  SG   28  DAL  14   0  14.6  1.9   4.1  ...  0.4
#
#       BLK  TOV   PF   PTS  Year  Avg GameScore               Name   Salaries  \
# 0     0.5  1.7  2.4  11.4  2000           7.39  Tariq Abdul-Wahad        NaN
# 1     0.3  1.9  2.5  12.2  2000           7.83  Tariq Abdul-Wahad        NaN
# 2     0.8  1.3  2.1   8.9  2000           5.59  Tariq Abdul-Wahad        NaN
# 404   0.4  1.2  1.9   3.8  2001           1.75  Tariq Abdul-Wahad  6480000.0
# 895   0.4  1.1  2.3   5.6  2002           3.58  Tariq Abdul-Wahad  7188750.0
# 896   0.5  1.2  2.6   6.8  2002           4.43  Tariq Abdul-Wahad  7188750.0
# 897   0.3  0.8  1.3   0.0  2002          -0.08  Tariq Abdul-Wahad  7188750.0
# 1371  0.2  0.5  1.9   4.1  2003           3.51  Tariq Abdul-Wahad  7818750.0
#
#       Rank
# 0      195
# 1      195
# 2      195
# 404    106
# 895     98
# 896     98
# 897     98
# 1371    93
#
# [8 rows x 35 columns]
